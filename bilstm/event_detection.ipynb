# %% [markdown]
# # Event detection

# %%
# This script trains the BiLSTM-CRF architecture for part-of-speech tagging using
# the universal dependency dataset (http://universaldependencies.org/).
# The code use the embeddings by Komninos et al. (https://www.cs.york.ac.uk/nlp/extvec/)
from __future__ import print_function
import os
import logging
import sys
from neuralnets.BiLSTM import BiLSTM
from util.preprocessing import perpareDataset, loadDatasetPickle

'''
# :: Change into the working dir of the script ::
abspath = os.path.abspath(__file__)
dname = os.path.dirname(abspath)
os.chdir(dname)
'''

# :: Logging level ::
loggingLevel = logging.INFO
logger = logging.getLogger()
logger.setLevel(loggingLevel)

ch = logging.StreamHandler(sys.stdout)
ch.setLevel(loggingLevel)
formatter = logging.Formatter('%(message)s')
ch.setFormatter(formatter)
logger.addHandler(ch)


######################################################
#
# Data preprocessing
#
######################################################
datasets = {
    'HistoMention':                                   #Name of the dataset
        {'columns': {0:'tokens', 1:'lemma', 2:'POS', 5:'chunk_BIO'},
         'label': 'chunk_BIO',                                #Which column we like to predict
         'evaluate': True,                                  #Should we evaluate on this task? Set true always for single task setups
         'commentSymbol': None} 
}


#Path on your computer to the word embeddings
embeddingsPath = 'glove.6B.300d.txt'#'HistoGlove.txt'

#Prepares the dataset to be used with the LSTM-network. Creates and stores cPickle files in the pkl/ folder ::
pickleFile = perpareDataset(embeddingsPath, datasets)


######################################################
#
# The training of the network starts here
#
######################################################


#Load the embeddings and the dataset
embeddings, mappings, data = loadDatasetPickle(pickleFile)

# Some network hyperparameters
params = {'classifier': ['Softmax'], 'LSTM-Size': [75, 75], 'dropout': (0.25, 0.25),
         'featureNames': ['tokens', 'lemma', 'casing', 'POS'], 'addFeatureDimensions': 10,
         'miniBatchSize': 64, 'earlyStopping': 10}

model = BiLSTM(params)
model.setMappings(mappings, embeddings)
model.setDataset(datasets, data)
model.storeResults('./unidep_pos_results.csv') #Path to store performance scores for dev / test
model.modelSavePath = "models/[ModelName]_[DevScore]_[TestScore]_[Epoch].h5" #Path to store models
model.fit(epochs=25)
# Out:
# Using TensorFlow backend.
# Using existent pickle file: pkl/HistoMention_glove.6B.300d.pkl
# --- HistoMention ---
# 1985 train sentences
# 258 dev sentences
# 257 test sentences
# LSTM-Size: [75, 75]
# _____________________________________________________________________________________________________________________________
# Layer (type)                             Output Shape               Param #        Connected to
# =============================================================================================================================
# words_input (InputLayer)                 (None, None)               0
# _____________________________________________________________________________________________________________________________
# lemma_input (InputLayer)                 (None, None)               0
# _____________________________________________________________________________________________________________________________
# casing_input (InputLayer)                (None, None)               0
# _____________________________________________________________________________________________________________________________
# POS_input (InputLayer)                   (None, None)               0
# _____________________________________________________________________________________________________________________________
# word_embeddings (Embedding)              (None, None, 300)          120000600      words_input[0][0]
# _____________________________________________________________________________________________________________________________
# lemma_emebddings (Embedding)             (None, None, 10)           77770          lemma_input[0][0]
# _____________________________________________________________________________________________________________________________
# casing_emebddings (Embedding)            (None, None, 10)           80             casing_input[0][0]
# _____________________________________________________________________________________________________________________________
# POS_emebddings (Embedding)               (None, None, 10)           460            POS_input[0][0]
# _____________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)              (None, None, 330)          0              word_embeddings[0][0]
#                                                                                    lemma_emebddings[0][0]
#                                                                                    casing_emebddings[0][0]
#                                                                                    POS_emebddings[0][0]
# _____________________________________________________________________________________________________________________________
# shared_varLSTM_1 (Bidirectional)         (None, None, 150)          243600         concatenate_1[0][0]
# _____________________________________________________________________________________________________________________________
# shared_varLSTM_2 (Bidirectional)         (None, None, 150)          135600         shared_varLSTM_1[0][0]
# _____________________________________________________________________________________________________________________________
# HistoMention_softmax (TimeDistributed)   (None, None, 3)            453            shared_varLSTM_2[0][0]
# =============================================================================================================================
# Total params: 120,458,563
# Trainable params: 457,963
# Non-trainable params: 120,000,600
# _____________________________________________________________________________________________________________________________
#
# --------- Epoch 1 -----------
# 9.87 sec for training (9.87 total)
# -- HistoMention --
# Wrong BIO-Encoding 4/1260 labels, 0.32%
# Wrong BIO-Encoding 2/1258 labels, 0.16%
# Train-Data: Prec: 0.385, Rec: 0.070, F1: 0.1182
# Dev-Data: Prec: 0.391, Rec: 0.075, F1: 0.1262
# Test-Data: Prec: 0.503, Rec: 0.088, F1: 0.1504
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.1182
#   Dev-Score: 0.1262
#
# 2.97 sec for evaluation
#
# --------- Epoch 2 -----------
# 4.75 sec for training (14.62 total)
# -- HistoMention --
# Wrong BIO-Encoding 73/7210 labels, 1.01%
# Wrong BIO-Encoding 68/7205 labels, 0.94%
# Train-Data: Prec: 0.720, Rec: 0.743, F1: 0.7312
# Wrong BIO-Encoding 12/879 labels, 1.37%
# Wrong BIO-Encoding 11/878 labels, 1.25%
# Dev-Data: Prec: 0.690, Rec: 0.682, F1: 0.6858
# Wrong BIO-Encoding 5/876 labels, 0.57%
# Wrong BIO-Encoding 5/876 labels, 0.57%
# Test-Data: Prec: 0.712, Rec: 0.712, F1: 0.7118
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.7312
#   Dev-Score: 0.6858
#
# 2.27 sec for evaluation
#
# --------- Epoch 3 -----------
# 4.74 sec for training (19.36 total)
# -- HistoMention --
# Wrong BIO-Encoding 223/7633 labels, 2.92%
# Wrong BIO-Encoding 204/7614 labels, 2.68%
# Train-Data: Prec: 0.772, Rec: 0.827, F1: 0.7988
# Wrong BIO-Encoding 30/952 labels, 3.15%
# Wrong BIO-Encoding 25/947 labels, 2.64%
# Dev-Data: Prec: 0.738, Rec: 0.775, F1: 0.7560
# Wrong BIO-Encoding 24/954 labels, 2.52%
# Wrong BIO-Encoding 24/954 labels, 2.52%
# Test-Data: Prec: 0.737, Rec: 0.786, F1: 0.7607
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.7988
#   Dev-Score: 0.7560
#
# 2.39 sec for evaluation
#
# --------- Epoch 4 -----------
# 4.75 sec for training (24.11 total)
# -- HistoMention --
# Wrong BIO-Encoding 276/7410 labels, 3.72%
# Wrong BIO-Encoding 246/7380 labels, 3.33%
# Train-Data: Prec: 0.811, Rec: 0.836, F1: 0.8233
# Wrong BIO-Encoding 33/896 labels, 3.68%
# Wrong BIO-Encoding 28/891 labels, 3.14%
# Dev-Data: Prec: 0.773, Rec: 0.761, F1: 0.7667
# Wrong BIO-Encoding 26/904 labels, 2.88%
# Wrong BIO-Encoding 25/903 labels, 2.77%
# Test-Data: Prec: 0.777, Rec: 0.783, F1: 0.7799
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.8233
#   Dev-Score: 0.7667
#
# 2.38 sec for evaluation
#
# --------- Epoch 5 -----------
# 4.77 sec for training (28.88 total)
# -- HistoMention --
# Wrong BIO-Encoding 397/7408 labels, 5.36%
# Wrong BIO-Encoding 333/7344 labels, 4.53%
# Train-Data: Prec: 0.849, Rec: 0.860, F1: 0.8544
# Wrong BIO-Encoding 57/912 labels, 6.25%
# Wrong BIO-Encoding 42/897 labels, 4.68%
# Dev-Data: Prec: 0.775, Rec: 0.756, F1: 0.7656
# Wrong BIO-Encoding 50/931 labels, 5.37%
# Wrong BIO-Encoding 44/925 labels, 4.76%
# Test-Data: Prec: 0.765, Rec: 0.774, F1: 0.7694
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.8544
#   Dev-Score: 0.7656
#
# 1.75 sec for evaluation
#
# --------- Epoch 6 -----------
# 4.70 sec for training (33.58 total)
# -- HistoMention --
# Wrong BIO-Encoding 370/7454 labels, 4.96%
# Wrong BIO-Encoding 312/7396 labels, 4.22%
# Train-Data: Prec: 0.855, Rec: 0.876, F1: 0.8655
# Wrong BIO-Encoding 64/927 labels, 6.90%
# Wrong BIO-Encoding 52/915 labels, 5.68%
# Dev-Data: Prec: 0.766, Rec: 0.754, F1: 0.7598
# Wrong BIO-Encoding 48/945 labels, 5.08%
# Wrong BIO-Encoding 45/942 labels, 4.78%
# Test-Data: Prec: 0.764, Rec: 0.786, F1: 0.7749
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.8655
#   Dev-Score: 0.7598
#
# 1.73 sec for evaluation
#
# --------- Epoch 7 -----------
# 4.74 sec for training (38.32 total)
# -- HistoMention --
# Wrong BIO-Encoding 251/7337 labels, 3.42%
# Wrong BIO-Encoding 207/7293 labels, 2.84%
# Train-Data: Prec: 0.867, Rec: 0.888, F1: 0.8771
# Wrong BIO-Encoding 30/882 labels, 3.40%
# Wrong BIO-Encoding 27/879 labels, 3.07%
# Dev-Data: Prec: 0.776, Rec: 0.754, F1: 0.7646
# Wrong BIO-Encoding 22/899 labels, 2.45%
# Wrong BIO-Encoding 21/898 labels, 2.34%
# Test-Data: Prec: 0.775, Rec: 0.781, F1: 0.7780
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.8771
#   Dev-Score: 0.7646
#
# 1.73 sec for evaluation
#
# --------- Epoch 8 -----------
# 4.71 sec for training (43.03 total)
# -- HistoMention --
# Wrong BIO-Encoding 238/7320 labels, 3.25%
# Wrong BIO-Encoding 204/7286 labels, 2.80%
# Train-Data: Prec: 0.875, Rec: 0.896, F1: 0.8857
# Wrong BIO-Encoding 29/882 labels, 3.29%
# Wrong BIO-Encoding 24/877 labels, 2.74%
# Dev-Data: Prec: 0.776, Rec: 0.755, F1: 0.7653
# Wrong BIO-Encoding 27/893 labels, 3.02%
# Wrong BIO-Encoding 24/890 labels, 2.70%
# Test-Data: Prec: 0.778, Rec: 0.774, F1: 0.7761
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.8857
#   Dev-Score: 0.7653
#
# 1.76 sec for evaluation
#
# --------- Epoch 9 -----------
# 4.87 sec for training (47.90 total)
# -- HistoMention --
# Wrong BIO-Encoding 294/7300 labels, 4.03%
# Wrong BIO-Encoding 252/7258 labels, 3.47%
# Train-Data: Prec: 0.891, Rec: 0.902, F1: 0.8962
# Wrong BIO-Encoding 30/893 labels, 3.36%
# Wrong BIO-Encoding 28/891 labels, 3.14%
# Dev-Data: Prec: 0.783, Rec: 0.771, F1: 0.7770
# Wrong BIO-Encoding 36/906 labels, 3.97%
# Wrong BIO-Encoding 32/902 labels, 3.55%
# Test-Data: Prec: 0.791, Rec: 0.790, F1: 0.7904
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.8962
#   Dev-Score: 0.7770
#
# 2.51 sec for evaluation
#
# --------- Epoch 10 -----------
# 4.93 sec for training (52.83 total)
# -- HistoMention --
# Wrong BIO-Encoding 250/7304 labels, 3.42%
# Wrong BIO-Encoding 197/7251 labels, 2.72%
# Train-Data: Prec: 0.897, Rec: 0.914, F1: 0.9055
# Wrong BIO-Encoding 41/910 labels, 4.51%
# Wrong BIO-Encoding 33/902 labels, 3.66%
# Dev-Data: Prec: 0.770, Rec: 0.763, F1: 0.7663
# Wrong BIO-Encoding 39/929 labels, 4.20%
# Wrong BIO-Encoding 35/925 labels, 3.78%
# Test-Data: Prec: 0.769, Rec: 0.785, F1: 0.7768
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9055
#   Dev-Score: 0.7663
#
# 1.78 sec for evaluation
#
# --------- Epoch 11 -----------
# 4.86 sec for training (57.69 total)
# -- HistoMention --
# Wrong BIO-Encoding 285/7253 labels, 3.93%
# Wrong BIO-Encoding 231/7199 labels, 3.21%
# Train-Data: Prec: 0.913, Rec: 0.920, F1: 0.9164
# Wrong BIO-Encoding 47/896 labels, 5.25%
# Wrong BIO-Encoding 38/887 labels, 4.28%
# Dev-Data: Prec: 0.783, Rec: 0.758, F1: 0.7706
# Wrong BIO-Encoding 50/904 labels, 5.53%
# Wrong BIO-Encoding 43/897 labels, 4.79%
# Test-Data: Prec: 0.789, Rec: 0.774, F1: 0.7814
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9164
#   Dev-Score: 0.7706
#
# 1.79 sec for evaluation
#
# --------- Epoch 12 -----------
# 4.85 sec for training (62.54 total)
# -- HistoMention --
# Wrong BIO-Encoding 217/7099 labels, 3.06%
# Wrong BIO-Encoding 176/7058 labels, 2.49%
# Train-Data: Prec: 0.922, Rec: 0.917, F1: 0.9194
# Wrong BIO-Encoding 22/851 labels, 2.59%
# Wrong BIO-Encoding 20/849 labels, 2.36%
# Dev-Data: Prec: 0.800, Rec: 0.756, F1: 0.7773
# Wrong BIO-Encoding 15/851 labels, 1.76%
# Wrong BIO-Encoding 14/850 labels, 1.65%
# Test-Data: Prec: 0.799, Rec: 0.767, F1: 0.7827
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9194
#   Dev-Score: 0.7773
#
# 2.35 sec for evaluation
#
# --------- Epoch 13 -----------
# 4.82 sec for training (67.37 total)
# -- HistoMention --
# Wrong BIO-Encoding 229/7150 labels, 3.20%
# Wrong BIO-Encoding 172/7093 labels, 2.42%
# Train-Data: Prec: 0.928, Rec: 0.928, F1: 0.9277
# Wrong BIO-Encoding 35/876 labels, 4.00%
# Wrong BIO-Encoding 28/869 labels, 3.22%
# Dev-Data: Prec: 0.794, Rec: 0.762, F1: 0.7776
# Wrong BIO-Encoding 32/877 labels, 3.65%
# Wrong BIO-Encoding 27/872 labels, 3.10%
# Test-Data: Prec: 0.791, Rec: 0.767, F1: 0.7786
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9277
#   Dev-Score: 0.7776
#
# 2.56 sec for evaluation
#
# --------- Epoch 14 -----------
# 4.90 sec for training (72.27 total)
# -- HistoMention --
# Wrong BIO-Encoding 239/7206 labels, 3.32%
# Wrong BIO-Encoding 179/7146 labels, 2.50%
# Train-Data: Prec: 0.933, Rec: 0.939, F1: 0.9359
# Wrong BIO-Encoding 38/901 labels, 4.22%
# Wrong BIO-Encoding 30/893 labels, 3.36%
# Dev-Data: Prec: 0.783, Rec: 0.771, F1: 0.7770
# Wrong BIO-Encoding 55/923 labels, 5.96%
# Wrong BIO-Encoding 47/915 labels, 5.14%
# Test-Data: Prec: 0.767, Rec: 0.765, F1: 0.7660
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9359
#   Dev-Score: 0.7770
#
# 1.73 sec for evaluation
#
# --------- Epoch 15 -----------
# 4.77 sec for training (77.04 total)
# -- HistoMention --
# Wrong BIO-Encoding 246/7189 labels, 3.42%
# Wrong BIO-Encoding 184/7127 labels, 2.58%
# Train-Data: Prec: 0.942, Rec: 0.945, F1: 0.9432
# Wrong BIO-Encoding 43/892 labels, 4.82%
# Wrong BIO-Encoding 32/881 labels, 3.63%
# Dev-Data: Prec: 0.793, Rec: 0.767, F1: 0.7798
# Wrong BIO-Encoding 36/898 labels, 4.01%
# Wrong BIO-Encoding 30/892 labels, 3.36%
# Test-Data: Prec: 0.773, Rec: 0.765, F1: 0.7686
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9432
#   Dev-Score: 0.7798
#
# 2.28 sec for evaluation
#
# --------- Epoch 16 -----------
# 4.83 sec for training (81.87 total)
# -- HistoMention --
# Wrong BIO-Encoding 215/7189 labels, 2.99%
# Wrong BIO-Encoding 160/7134 labels, 2.24%
# Train-Data: Prec: 0.944, Rec: 0.951, F1: 0.9472
# Wrong BIO-Encoding 28/886 labels, 3.16%
# Wrong BIO-Encoding 23/881 labels, 2.61%
# Dev-Data: Prec: 0.789, Rec: 0.772, F1: 0.7804
# Wrong BIO-Encoding 35/904 labels, 3.87%
# Wrong BIO-Encoding 29/898 labels, 3.23%
# Test-Data: Prec: 0.776, Rec: 0.774, F1: 0.7747
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9472
#   Dev-Score: 0.7804
#
# 2.81 sec for evaluation
#
# --------- Epoch 17 -----------
# 5.14 sec for training (87.00 total)
# -- HistoMention --
# Wrong BIO-Encoding 250/7157 labels, 3.49%
# Wrong BIO-Encoding 179/7086 labels, 2.53%
# Train-Data: Prec: 0.957, Rec: 0.956, F1: 0.9566
# Wrong BIO-Encoding 36/881 labels, 4.09%
# Wrong BIO-Encoding 26/871 labels, 2.99%
# Dev-Data: Prec: 0.787, Rec: 0.758, F1: 0.7724
# Wrong BIO-Encoding 46/900 labels, 5.11%
# Wrong BIO-Encoding 35/889 labels, 3.94%
# Test-Data: Prec: 0.793, Rec: 0.777, F1: 0.7849
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9566
#   Dev-Score: 0.7724
#
# 1.78 sec for evaluation
#
# --------- Epoch 18 -----------
# 4.76 sec for training (91.76 total)
# -- HistoMention --
# Wrong BIO-Encoding 206/7271 labels, 2.83%
# Wrong BIO-Encoding 148/7213 labels, 2.05%
# Train-Data: Prec: 0.948, Rec: 0.968, F1: 0.9584
# Wrong BIO-Encoding 24/927 labels, 2.59%
# Wrong BIO-Encoding 21/924 labels, 2.27%
# Dev-Data: Prec: 0.764, Rec: 0.787, F1: 0.7753
# Wrong BIO-Encoding 36/933 labels, 3.86%
# Wrong BIO-Encoding 30/927 labels, 3.24%
# Test-Data: Prec: 0.760, Rec: 0.783, F1: 0.7715
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9584
#   Dev-Score: 0.7753
#
# 1.71 sec for evaluation
#
# --------- Epoch 19 -----------
# 4.76 sec for training (96.52 total)
# -- HistoMention --
# Wrong BIO-Encoding 204/7201 labels, 2.83%
# Wrong BIO-Encoding 140/7137 labels, 1.96%
# Train-Data: Prec: 0.960, Rec: 0.971, F1: 0.9652
# Wrong BIO-Encoding 23/900 labels, 2.56%
# Wrong BIO-Encoding 18/895 labels, 2.01%
# Dev-Data: Prec: 0.773, Rec: 0.773, F1: 0.7731
# Wrong BIO-Encoding 33/916 labels, 3.60%
# Wrong BIO-Encoding 28/911 labels, 3.07%
# Test-Data: Prec: 0.768, Rec: 0.778, F1: 0.7731
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9652
#   Dev-Score: 0.7731
#
# 1.76 sec for evaluation
#
# --------- Epoch 20 -----------
# 4.76 sec for training (101.28 total)
# -- HistoMention --
# Wrong BIO-Encoding 245/7164 labels, 3.42%
# Wrong BIO-Encoding 175/7094 labels, 2.47%
# Train-Data: Prec: 0.968, Rec: 0.968, F1: 0.9678
# Wrong BIO-Encoding 48/895 labels, 5.36%
# Wrong BIO-Encoding 37/884 labels, 4.19%
# Dev-Data: Prec: 0.798, Rec: 0.771, F1: 0.7842
# Wrong BIO-Encoding 43/895 labels, 4.80%
# Wrong BIO-Encoding 39/891 labels, 4.38%
# Test-Data: Prec: 0.789, Rec: 0.772, F1: 0.7800
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9678
#   Dev-Score: 0.7842
#
# 2.31 sec for evaluation
#
# --------- Epoch 21 -----------
# 4.76 sec for training (106.04 total)
# -- HistoMention --
# Wrong BIO-Encoding 270/7114 labels, 3.80%
# Wrong BIO-Encoding 200/7044 labels, 2.84%
# Train-Data: Prec: 0.971, Rec: 0.961, F1: 0.9659
# Wrong BIO-Encoding 37/862 labels, 4.29%
# Wrong BIO-Encoding 34/859 labels, 3.96%
# Dev-Data: Prec: 0.795, Rec: 0.748, F1: 0.7709
# Wrong BIO-Encoding 34/859 labels, 3.96%
# Wrong BIO-Encoding 29/854 labels, 3.40%
# Test-Data: Prec: 0.796, Rec: 0.754, F1: 0.7748
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9659
#   Dev-Score: 0.7709
#
# 1.74 sec for evaluation
#
# --------- Epoch 22 -----------
# 4.73 sec for training (110.76 total)
# -- HistoMention --
# Wrong BIO-Encoding 242/7171 labels, 3.37%
# Wrong BIO-Encoding 170/7099 labels, 2.39%
# Train-Data: Prec: 0.973, Rec: 0.974, F1: 0.9733
# Wrong BIO-Encoding 42/897 labels, 4.68%
# Wrong BIO-Encoding 30/885 labels, 3.39%
# Dev-Data: Prec: 0.789, Rec: 0.770, F1: 0.7794
# Wrong BIO-Encoding 46/903 labels, 5.09%
# Wrong BIO-Encoding 38/895 labels, 4.25%
# Test-Data: Prec: 0.777, Rec: 0.765, F1: 0.7708
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9733
#   Dev-Score: 0.7794
#
# 1.71 sec for evaluation
#
# --------- Epoch 23 -----------
# 4.72 sec for training (115.48 total)
# -- HistoMention --
# Wrong BIO-Encoding 238/7222 labels, 3.30%
# Wrong BIO-Encoding 161/7145 labels, 2.25%
# Train-Data: Prec: 0.973, Rec: 0.982, F1: 0.9773
# Wrong BIO-Encoding 44/922 labels, 4.77%
# Wrong BIO-Encoding 33/911 labels, 3.62%
# Dev-Data: Prec: 0.781, Rec: 0.782, F1: 0.7818
# Wrong BIO-Encoding 49/932 labels, 5.26%
# Wrong BIO-Encoding 39/922 labels, 4.23%
# Test-Data: Prec: 0.762, Rec: 0.773, F1: 0.7674
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9773
#   Dev-Score: 0.7818
#
# 1.71 sec for evaluation
#
# --------- Epoch 24 -----------
# 4.73 sec for training (120.21 total)
# -- HistoMention --
# Wrong BIO-Encoding 217/7191 labels, 3.02%
# Wrong BIO-Encoding 154/7128 labels, 2.16%
# Train-Data: Prec: 0.977, Rec: 0.985, F1: 0.9811
# Wrong BIO-Encoding 42/916 labels, 4.59%
# Wrong BIO-Encoding 31/905 labels, 3.43%
# Dev-Data: Prec: 0.778, Rec: 0.775, F1: 0.7767
# Wrong BIO-Encoding 39/932 labels, 4.18%
# Wrong BIO-Encoding 34/927 labels, 3.67%
# Test-Data: Prec: 0.756, Rec: 0.775, F1: 0.7653
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9811
#   Dev-Score: 0.7767
#
# 1.71 sec for evaluation
#
# --------- Epoch 25 -----------
# 4.75 sec for training (124.96 total)
# -- HistoMention --
# Wrong BIO-Encoding 250/7186 labels, 3.48%
# Wrong BIO-Encoding 176/7112 labels, 2.47%
# Train-Data: Prec: 0.982, Rec: 0.985, F1: 0.9836
# Wrong BIO-Encoding 34/890 labels, 3.82%
# Wrong BIO-Encoding 29/885 labels, 3.28%
# Dev-Data: Prec: 0.783, Rec: 0.764, F1: 0.7732
# Wrong BIO-Encoding 37/904 labels, 4.09%
# Wrong BIO-Encoding 32/899 labels, 3.56%
# Test-Data: Prec: 0.777, Rec: 0.774, F1: 0.7756
#
# Scores from epoch with best dev-scores:
#   Train-Score: 0.9836
#   Dev-Score: 0.7732
#
# 1.72 sec for evaluation
